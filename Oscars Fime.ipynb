# %%
# %pip install pandas requests numpy lxml beautifulsoup4 html5lib
# Out:
# Requirement already satisfied: pandas in ./venv/lib/python3.13/site-packages (3.0.0)
# Requirement already satisfied: requests in ./venv/lib/python3.13/site-packages (2.32.5)
# Requirement already satisfied: numpy in ./venv/lib/python3.13/site-packages (2.4.2)
# Requirement already satisfied: lxml in ./venv/lib/python3.13/site-packages (6.0.2)
# Requirement already satisfied: beautifulsoup4 in ./venv/lib/python3.13/site-packages (4.14.3)
# Collecting html5lib
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.13/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.13/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.13/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.13/site-packages (from requests) (2026.1.4)
# Requirement already satisfied: soupsieve>=1.6.1 in ./venv/lib/python3.13/site-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./venv/lib/python3.13/site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: six>=1.9 in ./venv/lib/python3.13/site-packages (from html5lib) (1.17.0)
# Requirement already satisfied: webencodings in ./venv/lib/python3.13/site-packages (from html5lib) (0.5.1)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Installing collected packages: html5lib
# Successfully installed html5lib-1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
import numpy as np
import io

# %%
url_wiki = "https://kt.ijs.si/~ljupco/lectures/appr-2324/dn1-viri/List%20of%20Academy%20Award-winning%20films%20-%20Wikipedia.html"
headers = {"User-Agent": "Mozilla/5.0"}

resp_wiki = requests.get(url_wiki, headers=headers)
resp_wiki.raise_for_status()

# Essa página tem mais de uma tabela; a que queremos é a com colunas Film / Year / Awards / Nominations
tables_wiki = pd.read_html(io.StringIO(resp_wiki.text))

oscars = tables_wiki[0].copy()
oscars
# Out:
#                                                    Film  Year Awards  \
# 0                     Everything Everywhere All at Once  2022      7
# 1                        All Quiet on the Western Front  2022      4
# 2                                             The Whale  2022      2
# 3                                     Top Gun: Maverick  2022      1
# 4                        Black Panther: Wakanda Forever  2022      1
# ...                                                 ...   ...    ...
# 1355                            The Yankee Doodle Mouse  1943      1
# 1356                                       The Yearling  1946      2
# 1357  Yesterday, Today and Tomorrow (Ieri, oggi, dom...  1964      1
# 1358                         You Can't Take It with You  1938      2
# 1359                    Zorba the Greek (Alexis Zorbas)  1964      3
#
#      Nominations
# 0             11
# 1              9
# 2              3
# 3              6
# 4              5
# ...          ...
# 1355           1
# 1356           7
# 1357           1
# 1358           7
# 1359           7
#
# [1360 rows x 4 columns]

# %%
# Remove qualquer texto entre parênteses em Awards (casos tipo "0 (1)")
oscars["Awards_clean"] = (
    oscars["Awards"]
    .astype(str)
    .str.replace(r"\s*\(.*\)", "", regex=True)
)

# Converte para numérico, forçando erros para NaN
oscars["Awards_clean"] = pd.to_numeric(oscars["Awards_clean"], errors="coerce")
oscars["Nominations_clean"] = pd.to_numeric(oscars["Nominations"], errors="coerce")

# Remove linhas sem números válidos
oscars_num = oscars.dropna(subset=["Awards_clean", "Nominations_clean"]).copy()

# ---------------------------------------------------
# 2) Min–max normalization de Awards e Nominations
# ---------------------------------------------------

def minmax(col):
    return (col - col.min()) / (col.max() - col.min())

oscars_num["Awards_norm"] = minmax(oscars_num["Awards_clean"])
oscars_num["Nominations_norm"] = minmax(oscars_num["Nominations_clean"])

# Exemplo de score composto (50% wins, 50% indicações)
oscars_num["Score_norm"] = 0.5 * oscars_num["Awards_norm"] + 0.5 * oscars_num["Nominations_norm"]

# Top 10 filmes com maior score normalizado
oscars_num.sort_values("Score_norm", ascending=False).head(10)
# Out:
#                                                Film  Year Awards Nominations  \
# 365                                         Titanic  1997     11          14
# 855                                         Ben-Hur  1959     11          12
# 283   The Lord of the Rings: The Return of the King  2003     11          11
# 1328                                West Side Story  1961     10          11
# 376                             The English Patient  1996      9          12
# 977                           From Here to Eternity  1953      8          13
# 994                              Gone with the Wind  1939  8 (2)          13
# 1132                                   My Fair Lady  1964      8          12
# 1154                              On the Waterfront  1954      8          12
# 353                             Shakespeare in Love  1998      7          13
#
#       Awards_clean  Nominations_clean  Awards_norm  Nominations_norm  \
# 365           11.0               14.0     1.000000          1.000000
# 855           11.0               12.0     1.000000          0.857143
# 283           11.0               11.0     1.000000          0.785714
# 1328          10.0               11.0     0.909091          0.785714
# 376            9.0               12.0     0.818182          0.857143
# 977            8.0               13.0     0.727273          0.928571
# 994            8.0               13.0     0.727273          0.928571
# 1132           8.0               12.0     0.727273          0.857143
# 1154           8.0               12.0     0.727273          0.857143
# 353            7.0               13.0     0.636364          0.928571
#
#       Score_norm
# 365     1.000000
# 855     0.928571
# 283     0.892857
# 1328    0.847403
# 376     0.837662
# 977     0.827922
# 994     0.827922
# 1132    0.792208
# 1154    0.792208
# 353     0.782468

# %%
# ---------------------------------------------------
# 3) Tabela: Best Picture Oscar Winners (The Numbers)
# ---------------------------------------------------

url_numbers = "https://www.the-numbers.com/movies/comparisons/Best-Picture-Oscar-Winners"
resp_num = requests.get(url_numbers, headers=headers)
resp_num.raise_for_status()

tables_num = pd.read_html(io.StringIO(resp_num.text))

# Procure a tabela com filmes/ano/budget/box office etc.
for i, t in enumerate(tables_num):
    print(i, t.columns)

# Suponha que a tabela principal seja tables_num[0] (ajuste após inspeção)
bp = tables_num[0].copy()
bp.head()
# Out:
# 0 Index(['Release Date', 'Movie', 'Production Budget',
#        'Domestic Opening Weekend', 'Domestic Box Office',
#        'Worldwide Box Office', 'Trailer'],
#       dtype='str')
#    Release Date                     Movie Production Budget  \
# 0  Oct 22, 1964              My Fair Lady       $17,000,000
# 1   Mar 2, 1965        The Sound of Music        $8,200,000
# 2  Dec 12, 1966     A Man for All Seasons        $3,900,000
# 3   Aug 2, 1967  In the Heat of the Night        $2,000,000
# 4  Dec 11, 1968                   Oliver!       $10,000,000
#
#   Domestic Opening Weekend Domestic Box Office Worldwide Box Office Trailer
# 0                      NaN         $72,000,000          $72,073,063     NaN
# 1                      NaN        $164,815,523         $287,814,441     NaN
# 2                      NaN         $28,350,000          $28,350,000     NaN
# 3                      NaN         $24,379,978          $24,407,647     NaN
# 4                      NaN         $37,402,877          $37,402,877     NaN

# %%
# Realiza o merge (join) entre os dataframes
oscars_num = oscars_num.merge(
    bp[['Movie', 'Worldwide Box Office']], # Selecionamos apenas as colunas necessárias de bp
    left_on='Film',                       # Coluna de busca no oscars_num
    right_on='Movie',                     # Coluna de busca no bp
    how='left'                            # Mantém todos os filmes da lista de Oscars
)

# Remove a coluna 'Movie' que fica duplicada após o merge
oscars_num = oscars_num.drop(columns='Movie')

# Remove as linhas em que não há o valor para essa(s) coluna(s)
oscars_num = oscars_num.dropna(subset=['Worldwide Box Office']).copy()

# Visualiza o resultado
oscars_num.head()
# Out:
#                   Film     Year Awards Nominations  Awards_clean  \
# 13                CODA     2021      3           3           3.0
# 28           Nomadland  2020/21      3           6           3.0
# 59          Green Book     2018      3           5           3.0
# 74  The Shape of Water     2017      4          13           4.0
# 89           Moonlight     2016      3           8           3.0
#
#     Nominations_clean  Awards_norm  Nominations_norm  Score_norm  \
# 13                3.0     0.272727          0.214286    0.243506
# 28                6.0     0.272727          0.428571    0.350649
# 59                5.0     0.272727          0.357143    0.314935
# 74               13.0     0.363636          0.928571    0.646104
# 89                8.0     0.272727          0.571429    0.422078
#
#    Worldwide Box Office_x Worldwide Box Office_y Worldwide Box Office
# 13             $2,237,618             $2,237,618           $2,237,618
# 28            $38,728,987            $38,728,987          $38,728,987
# 59           $319,995,019           $319,995,019         $319,995,019
# 74           $195,790,794           $195,790,794         $195,790,794
# 89            $64,828,447            $64,828,447          $64,828,447
